# %%
pip install -U spacy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 2.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 2.2 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.7/863.7 kB 3.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.2
#     Uninstalling catalogue-1.0.2:
#       Successfully uninstalled catalogue-1.0.2
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.7
#     Uninstalling srsly-1.0.7:
#       Successfully uninstalled srsly-1.0.7
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.6
#     Uninstalling thinc-7.4.6:
#       Successfully uninstalled thinc-7.4.6
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.3.9
# ...

# %%
# !pip install pipreqs
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.5 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=434a92ed1302e85ffe7664b5601fd3f638a4f78ffacca47522c1a0e004ccbb90
#   Stored in directory: /Users/bhoomikaraval/Library/Caches/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# ...
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.22.1
#     Uninstalling ipython-8.22.1:
#       Successfully uninstalled ipython-8.22.1
# ...

# %%
# !pipreqs '/Users/bhoomikaraval/Resume_screener/Resume-JD-App'
# Out:
# INFO: Not scanning for jupyter notebooks.
# WARNING: Import named "beautifulsoup4" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "beautifulsoup4" was resolved to "beautifulsoup4:4.12.3" package (https://pypi.org/project/beautifulsoup4/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "cohere" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "cohere" was resolved to "cohere:5.3.2" package (https://pypi.org/project/cohere/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "langchain" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "langchain" was resolved to "langchain:0.1.16" package (https://pypi.org/project/langchain/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# ...

# %%
# !python3 -m spacy validate
# Out:
# ✔ Loaded compatibility table
#
# ================= Installed pipeline packages (spaCy v3.7.4) =================
# ℹ spaCy installation: /usr/local/lib/python3.11/site-packages/spacy
#
# NAME             SPACY            VERSION
# en_core_web_md   >=3.6.0,<3.7.0   3.6.0   --> 3.7.1
#
#
# ============================== Install updates ==============================
# Use the following commands to update the packages:
# python -m spacy download en_core_web_md

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 7.5 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.3.1
#     Uninstalling en-core-web-sm-2.3.1:
#       Successfully uninstalled en-core-web-sm-2.3.1
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
